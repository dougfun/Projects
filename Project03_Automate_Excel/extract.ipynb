# %%
import os
import openpyxl as xl
import pdfplumber

# %%
# Searching for pdf files
for pdf_file in os.listdir('pdfs'):

    if pdf_file.endswith('.pdf'):
    
        excel = xl.load_workbook(r'C:\Users\dougi\Desktop\Project03\database_inspections.xlsx')
        tab = excel.active

        initial_line = len(tab['A']) + 1

        pdf = pdfplumber.open(f'pdfs\\{pdf_file}')
        page = pdf.pages[0] # Our pdf onyl has one page

        pdf_data = page.extract_table()

        for index, data in enumerate(pdf_data[1:], start = initial_line):
            if data[0] == '':
                pass
            else:
                tab.cell(row = index, column = 1).value = data[0]
                tab.cell(row = index, column = 2).value = data[1]
                tab.cell(row = index, column = 3).value = data[2]
                tab.cell(row = index, column = 4).value = data[3]
                tab.cell(row = index, column = 5).value = data[4]
                print(data)
        
        pdf.close()
        excel.save(r'C:\Users\dougi\Desktop\Project03\database_inspections.xlsx')
        excel.close()
    else:
        pass
# Out:
# ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala 1', 'Aprovado']
# ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala 2', 'Aprovado']
# ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala3', 'Aprovado']
# ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala 4', 'Aprovado']
# ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Banheiro', 'Reprovado']
# ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Refeitório', 'Aprovado']
# ['01/01/2022', 'Empresa A', 'Recursos Humanos', 'Sala 5', 'Aprovado']
# ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Sala 1', 'Aprovado']
# ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Sala 2', 'Aprovado']
# ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Sala 3', 'Aprovado']
# ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Banheiro', 'Reprovado']
# ['02/02/2022', 'Empresa A', 'Tecnologia da Informação', 'Refeitório', 'Aprovado']
# ['03/02/2022', 'Empresa A', 'Galpão I', 'Aréa descarga', 'Aprovado']
# ['03/02/2022', 'Empresa A', 'Galpão I', 'Sala 1', 'Aprovado']
# ['03/02/2022', 'Empresa A', 'Galpão I', 'Sala 2', 'Aprovado']
# ['03/02/2022', 'Empresa A', 'Galpão I', 'Sala 3', 'Aprovado']
# ['03/02/2022', 'Empresa A', 'Galpão I', 'Área carga', 'Aprovado']
# ['03/02/2022', 'Empresa A', 'Galpão I', 'Refeitório', 'Aprovado']
# ['03/02/2022', 'Empresa A', 'Galpão I', 'Banheiro', 'Reprovado']
# ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala 1', 'Aprovado']
# ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala 2', 'Aprovado']
# ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala3', 'Aprovado']
# ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala 4', 'Aprovado']
# ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Banheiro', 'Reprovado']
# ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Refeitório', 'Aprovado']
# ['01/03/2022', 'Empresa B', 'Recursos Humanos', 'Sala 5', 'Aprovado']
# ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Sala 1', 'Aprovado']
# ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Sala 2', 'Aprovado']
# ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Sala 3', 'Aprovado']
# ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Banheiro', 'Reprovado']
# ['02/04/2022', 'Empresa B', 'Tecnologia da Informação', 'Refeitório', 'Aprovado']
# ['03/04/2022', 'Empresa B', 'Galpão I', 'Aréa descarga', 'Aprovado']
# ['03/04/2022', 'Empresa B', 'Galpão I', 'Sala 1', 'Aprovado']
# ['03/04/2022', 'Empresa B', 'Galpão I', 'Sala 2', 'Aprovado']
# ['03/04/2022', 'Empresa B', 'Galpão I', 'Sala 3', 'Aprovado']
# ['03/04/2022', 'Empresa B', 'Galpão I', 'Área carga', 'Aprovado']
# ['03/04/2022', 'Empresa B', 'Galpão I', 'Refeitório', 'Aprovado']
# ['03/04/2022', 'Empresa B', 'Galpão I', 'Banheiro', 'Reprovado']
# ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 1', 'Aprovado']
# ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 2', 'Aprovado']
# ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 3', 'Aprovado']
# ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 4', 'Aprovado']
# ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 5', 'Aprovado']
# ['05/04/2022', 'Empresa B', 'Financeiro', 'Sala 6', 'Aprovado']
# ['05/04/2022', 'Empresa B', 'Financeiro', 'Auditório', 'Aprovado']
# ['05/04/2022', 'Empresa B', 'Financeiro', 'Refeitório', 'Reprovado']
# ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala 1', 'Aprovado']
# ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala 2', 'Aprovado']
# ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala3', 'Aprovado']
# ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala 4', 'Aprovado']
# ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Banheiro', 'Aprovado']
# ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Refeitório', 'Aprovado']
# ['05/06/2022', 'Empresa C', 'Recursos Humanos', 'Sala 5', 'Aprovado']
# ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Sala 1', 'Aprovado']
# ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Sala 2', 'Aprovado']
# ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Sala 3', 'Aprovado']
# ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Banheiro', 'Aprovado']
# ['06/06/2022', 'Empresa C', 'Tecnologia da Informação', 'Refeitório', 'Aprovado']
# ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala 1', 'Aprovado']
# ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala 2', 'Aprovado']
# ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala3', 'Aprovado']
# ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala 4', 'Aprovado']
# ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Banheiro', 'Aprovado']
# ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Refeitório', 'Aprovado']
# ['07/07/2022', 'Empresa D', 'Recursos Humanos', 'Sala 5', 'Aprovado']
# ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Sala 1', 'Aprovado']
# ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Sala 2', 'Aprovado']
# ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Sala 3', 'Aprovado']
# ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Banheiro', 'Aprovado']
# ['08/07/2022', 'Empresa D', 'Tecnologia da Informação', 'Refeitório', 'Aprovado']
# ['09/07/2022', 'Empresa D', 'Suprimentos', 'Sala 1', 'Aprovado']
# ['09/07/2022', 'Empresa D', 'Suprimentos', 'Sala 2', 'Aprovado']
# ['09/07/2022', 'Empresa D', 'Suprimentos', 'Sala 3', 'Reprovado']
# ['09/07/2022', 'Empresa D', 'Suprimentos', 'Auditório', 'Aprovado']
# ['09/07/2022', 'Empresa D', 'Suprimentos', 'Refeitório', 'Reprovado']
# ['09/07/2022', 'Empresa D', 'Suprimentos', 'Banheiro', 'Reprovado']
